# %% [markdown]
# # Task 1 and 2

# %% [markdown]
# ### Importing DataGenerator

# %%
import DataGenerator as dg

# %% [markdown]
# ### Initializing class

# %%
my_class = dg.DataGenerator(n_points = 1000)

# %% [markdown]
# ### Plotting histogram

# %%
list_of_points = my_class.random_2d_point_gen()
my_class.plot_histogram(list_of_points, bins = 20)

# %% [markdown]
# ### Ploting heatmap

# %%
my_class.plot_heatmap(list_of_points)
