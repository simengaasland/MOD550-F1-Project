# %% [markdown]
# # Task 3, 4 and 5

# %% [markdown]
# ### Importing DataAquisition

# %%
import data_aquisition as da

# %% [markdown]
# ### Initializing class

# %%
monza_gp = da.DataAquisition(gp = 'Monza', year = 2025)
monaco_gp = da.DataAquisition(gp = 'Monaco', year = 2025)
silverstone_gp = da.DataAquisition(gp = 'Silverstone', year = 2025)

# %% [markdown]
# ### Plotting histogram

# %% [markdown]
# FastF1 print out alot of pink messages. Ignore them for the time being. I am currently working on removing them. Just scoll down the see the histograms.

# %%
bins = 12 

monza_gp.plot_histogram(bins)
monaco_gp.plot_histogram(bins)
silverstone_gp.plot_histogram(bins)
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (500.23 MB) C:\Users\simen\AppData\Local\Temp\fastf1
# core           INFO 	Loading data for Italian Grand Prix - Practice 1 [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 3
# core        WARNING 	No lap data for driver 7
# core        WARNING 	No lap data for driver 9
# core        WARNING 	No lap data for driver 11
# core        WARNING 	No lap data for driver 15
# core        WARNING 	No lap data for driver 17
# core        WARNING 	No lap data for driver 19
# core        WARNING 	No lap data for driver 21
# ...

# %% [markdown]
# ### Plotting PMF

# %% [markdown]
# Ignore pink messages. Scroll to see PMF

# %%
monza_gp.plot_pmf(bins)
monaco_gp.plot_pmf(bins)
silverstone_gp.plot_pmf(bins)
# Out:
# core           INFO 	Loading data for Italian Grand Prix - Practice 1 [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 3
# core        WARNING 	No lap data for driver 7
# core        WARNING 	No lap data for driver 9
# core        WARNING 	No lap data for driver 11
# core        WARNING 	No lap data for driver 15
# core        WARNING 	No lap data for driver 17
# core        WARNING 	No lap data for driver 19
# core        WARNING 	No lap data for driver 21
# core        WARNING 	No lap data for driver 25
# core        WARNING 	No lap data for driver 29
# ...

# %% [markdown]
# ### Plotting cumulative PMF

# %% [markdown]
# Ignore pink messages. Scroll to see cumulative PMF

# %%
monza_gp.plot_cumulative_pmf(bins)
monaco_gp.plot_cumulative_pmf(bins)
silverstone_gp.plot_cumulative_pmf(bins)
# Out:
# core           INFO 	Loading data for Italian Grand Prix - Practice 1 [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 3
# core        WARNING 	No lap data for driver 7
# core        WARNING 	No lap data for driver 9
# core        WARNING 	No lap data for driver 11
# core        WARNING 	No lap data for driver 15
# core        WARNING 	No lap data for driver 17
# core        WARNING 	No lap data for driver 19
# core        WARNING 	No lap data for driver 21
# core        WARNING 	No lap data for driver 25
# core        WARNING 	No lap data for driver 29
# ...
